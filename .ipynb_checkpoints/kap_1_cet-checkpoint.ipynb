# %% [markdown]
# Kappa 1 Ceti is on the list and is a good proxy for on of the mMEATS stars. Lots of archival data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
from astropy.convolution import convolve, Box1DKernel
from scipy.interpolate import interp1d

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting
from matplotlib.gridspec import GridSpec


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
star = 'HIP-15457'

# %%
#tom ayres stis uv

# %%
uvpath ='/media/david/2tb_ext_hd/hddata/hwo/data/hst/HIP-15457/tayres/'
tspec = fits.getdata('{}h_hd20630_uvsum_1x_51806_spc.fits'.format(uvpath), 1)[0]

# %%
w_uv, f_uv, e_uv = tspec['WAVE'], tspec['FLUX'], tspec['ERROR']
plt.step(w_uv, f_uv, where='mid')
plt.step(w_uv, e_uv, where='mid')

plt.yscale('log')
plt.xscale('log')

# %% [markdown]
# Some CCD data I need to re-extract

# %%
path = '/media/david/2tb_ext_hd/hddata/hwo/data/hst/HIP-15457/stis/'

# %%
import stistools

# %%
os.environ['oref'] = path

# %%
roots = ['O8RU3X010', 'O8RU3XHCQ', 'O8RU3XHDQ']

for i, root in  enumerate(roots):
    root = root.lower()
    flt = '{}/{}_flt.fits'.format(path, root)
    SPTRCTAB = fits.getheader(flt,0)['SPTRCTAB']
    grating = fits.getheader(flt,0)['OPT_ELEM']
    cenwave = fits.getheader(flt,0)['CENWAVE']
#     tracegrid = build_trace_grid(path+SPTRCTAB[5:], grating, cenwave)
    rootname = fits.getheader(flt)['ROOTNAME'] 
    outname = 'reextractions/kap1cet/{}_new_x1d.fits'.format(rootname)
    if os.path.exists(outname):
        os.remove(outname)
#     a2center = get_a2center(xs[i],ys[i], tracegrid)
#     print(root)
#     print(a2center)
    # a2center = 375
    stistools.x1d.x1d(flt, output = outname, trailer='reextractions/kap1cet/{}_new.trl'.format(rootname), bksmode='off')
    
    data = fits.getdata(outname, 1)[0]
    w, f, e= data['WAVELENGTH'], data['FLUX'], data['ERROR']
    mask = w > 1150 
    w, f, e = w[mask], f[mask], e[mask]
    
    plt.step(w, f, where='mid', alpha=0.5)
    
# plt.xlim(1150, 1250)
# plt.ylim(-0.1e-15, 0.5e-15)
# plt.axhline(0, ls='--', c='0.5')
       

    
# # data = Table(fits.getdata('draft_hlsp/kap1cet/hlsp_muscles_hst_stis_wasp-121_g140l_v1_component-spec.fits', 1))



# w, f, e= data['WAVELENGTH'], data['FLUX'], data['ERROR']

# plt.step(w[w > 1150], f[w > 1150], where='mid')

# %% [markdown]
# Need to defringe as well. Script it up?

# %%
# for i, x in enumerate(g750ls):

x = '{}o8ru3xhdq_raw_2_x1d.fits'.format(path)

hdr = fits.getheader(x, 0)
root = hdr['ROOTNAME']
flat = hdr['FRNGFLAT']
print(hdr['ROOTNAME'], hdr['FRNGFLAT'])
flatpath = '{}{}'.format(path, flat.lower())
scipath = '{}{}'.format(path, root)
stistools.defringe.normspflat('{}_raw.fits'.format(flatpath),
                          '{}_nsp.fits'.format(flatpath), do_cal=True,
                          wavecal='{}_wav.fits'.format(scipath))
with fits.open('{}_nsp.fits'.format(flatpath), mode='update') as hdulist:
    hdulist[1].data[:,:250] = 1
    
    
stistools.defringe.prepspec('{}{}_raw.fits'.format(path, root))
    
mode = fits.getheader('{}_raw.fits'.format(scipath),0)['OPT_ELEM']
if mode == "G750L":
    prod_type = "crj"
elif mode == "G750M":
    prod_type = "sx2"
# prod_type='raw_2_x2d'


if os.path.exists('{}_frr.fits'.format(flatpath)):
    os.remove('{}_frr.fits'.format(flatpath))

stistools.defringe.mkfringeflat('{}_{}.fits'.format(scipath, prod_type), '{}_nsp.fits'.format(flatpath),
                                '{}_frr.fits'.format(flatpath), beg_shift=-0.5, end_shift=2, shift_step=0.1,
                                beg_scale=0.8, end_scale=1.7, scale_step=0.04)

stistools.defringe.defringe('{}_{}.fits'.format(scipath, prod_type), '{}_frr.fits'.format(flatpath), overwrite=True)

outpath = '{}defringed/'.format(path)
outname = '{}{}_defringed_x1d.fits'.format(outpath, root)

if os.path.exists(outname):
    os.remove(outname)

drj = '{}_drj.fits'.format(scipath)
trl = '{}{}.trl'.format(outpath, root)
stistools.x1d.x1d(drj, output = outname, trailer=trl)

fig, ax = plt.subplots()
olddata = fits.getdata(x, 1)[0]
w0, f0 , e0 = olddata['WAVELENGTH'], olddata['FLUX'], olddata['ERROR']

newdata = fits.getdata(outname, 1)[0]
w1, f1 , e1 = newdata['WAVELENGTH'], newdata['FLUX'], newdata['ERROR']

plt.plot(w0, f0)
plt.plot(w0, e0)
plt.plot(w1, f1)
plt.plot(w1, e1)
plt.show()
# Out:
# o8ru3xhdq O8RU3X070
# File written:  /media/david/2tb_ext_hd/hddata/hwo/data/hst/HIP-15457/stis/o8ru3x070_crj.fits
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:29:01 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:29:01 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     ERROR    Output file `./o8ru3xhdq_flt.fits' already exists.
#     calstis0 failed.
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:29:42 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:29:42 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     ERROR    Output file `./o8ru3xhdq_flt.fits' already exists.
#     calstis0 failed.
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:30:24 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:30:24 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     OBSMODE  ACCUM
#     APERTURE 52X0.2
#     OPT_ELEM G750L
#     DETECTOR CCD
#
#     Imset 1  Begin 14:30:24 MDT
#     Epcfile  o8ru3xhdj_epc.fits
#
#     CCDTAB   oref$0841734do_ccd.fits
#     CCDTAB   PEDIGREE=INFLIGHT 12/07/2001 20/07/2002
#     CCDTAB   DESCRIP =Updated readnoise for gain={1,4}, all amps, binning=1x1------------
#     CCDTAB   DESCRIP =all bias frames; gain calibration from prop 9611
#     Warning  Only one imset, so CRCORR will be reset to SKIPPED.
#
#     DQICORR  PERFORM
#     DQITAB   oref$h1v11475o_bpx.fits
#     DQITAB   PEDIGREE=GROUND
#     DQITAB   DESCRIP =Prel. Ground Calib
#     DQICORR  COMPLETE
#
#     ATODCORR OMIT
#
#     BLEVCORR PERFORM
#     Warning  (blevcorr) No virtual overscan region; \
#     Warning  no correction for slope will be applied.
#              Bias level from overscan has been subtracted; \
#              mean of bias levels subtracted was 1520.18.
#     BLEVCORR COMPLETE
#              Uncertainty array initialized, readnoise=7.6399, gain=4.021
#
#     BIASCORR PERFORM
#     BIASFILE oref$o2o1502to_bia.fits
#     BIASFILE PEDIGREE=INFLIGHT 24/01/2004 08/02/2004
#     BIASFILE DESCRIP =Reference file created by STIS bias pipeline
#     BIASCORR COMPLETE
#
#     DARKCORR PERFORM
#     DARKFILE oref$u691336co_drk.fits
#     DARKFILE PEDIGREE=INFLIGHT 24/01/2004 01/02/2004
#     DARKFILE DESCRIP =Weekly Dark created with the Dark Reference File Pipeline----------
#     DARKCORR COMPLETE
#
#     FLATCORR PERFORM
#     PFLTFILE oref$n491401no_pfl.fits
#     PFLTFILE PEDIGREE=INFLIGHT 16/08/2001 25/11/2002
#     PFLTFILE DESCRIP =ON-ORBIT CCD P-FLAT
#     LFLTFILE oref$pcc2026ko_lfl.fits
#     LFLTFILE PEDIGREE=INFLIGHT 27/05/1997 27/05/1997
#     LFLTFILE DESCRIP =CCD G750L Low-Order Flat
#     FLATCORR COMPLETE
#
#     SHADCORR OMIT
#
#     PHOTCORR OMIT
#
#     STATFLAG PERFORM
#     STATFLAG COMPLETE
#     Imset 1  End 14:30:24 MDT
#
#     End      25-Aug-2023 14:30:24 MDT
#
#     *** CALSTIS-1 complete ***
#
#     End      25-Aug-2023 14:30:24 MDT
#
#     *** CALSTIS-0 complete ***
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:33:44 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:33:44 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     ERROR    Output file `./o8ru3xhdq_flt.fits' already exists.
#     calstis0 failed.
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:34:10 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:34:10 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     OBSMODE  ACCUM
#     APERTURE 52X0.2
#     OPT_ELEM G750L
#     DETECTOR CCD
#
#     Imset 1  Begin 14:34:10 MDT
#     Epcfile  o8ru3xhdj_epc.fits
#
#     CCDTAB   oref$0841734do_ccd.fits
#     CCDTAB   PEDIGREE=INFLIGHT 12/07/2001 20/07/2002
#     CCDTAB   DESCRIP =Updated readnoise for gain={1,4}, all amps, binning=1x1------------
#     CCDTAB   DESCRIP =all bias frames; gain calibration from prop 9611
#     Warning  Only one imset, so CRCORR will be reset to SKIPPED.
#
#     DQICORR  PERFORM
#     DQITAB   oref$h1v11475o_bpx.fits
#     DQITAB   PEDIGREE=GROUND
#     DQITAB   DESCRIP =Prel. Ground Calib
#     DQICORR  COMPLETE
#
#     ATODCORR OMIT
#
#     BLEVCORR PERFORM
#     Warning  (blevcorr) No virtual overscan region; \
#     Warning  no correction for slope will be applied.
#              Bias level from overscan has been subtracted; \
#              mean of bias levels subtracted was 1520.18.
#     BLEVCORR COMPLETE
#              Uncertainty array initialized, readnoise=7.6399, gain=4.021
#
#     BIASCORR PERFORM
#     BIASFILE oref$o2o1502to_bia.fits
#     BIASFILE PEDIGREE=INFLIGHT 24/01/2004 08/02/2004
#     BIASFILE DESCRIP =Reference file created by STIS bias pipeline
#     BIASCORR COMPLETE
#
#     DARKCORR PERFORM
#     DARKFILE oref$u691336co_drk.fits
#     DARKFILE PEDIGREE=INFLIGHT 24/01/2004 01/02/2004
#     DARKFILE DESCRIP =Weekly Dark created with the Dark Reference File Pipeline----------
#     DARKCORR COMPLETE
#
#     FLATCORR PERFORM
#     PFLTFILE oref$n491401no_pfl.fits
#     PFLTFILE PEDIGREE=INFLIGHT 16/08/2001 25/11/2002
#     PFLTFILE DESCRIP =ON-ORBIT CCD P-FLAT
#     LFLTFILE oref$pcc2026ko_lfl.fits
#     LFLTFILE PEDIGREE=INFLIGHT 27/05/1997 27/05/1997
#     LFLTFILE DESCRIP =CCD G750L Low-Order Flat
#     FLATCORR COMPLETE
#
#     SHADCORR OMIT
#
#     PHOTCORR OMIT
#
#     STATFLAG PERFORM
#     STATFLAG COMPLETE
#     Imset 1  End 14:34:10 MDT
#
#     End      25-Aug-2023 14:34:10 MDT
#
#     *** CALSTIS-1 complete ***
#
#     End      25-Aug-2023 14:34:10 MDT
#
#     *** CALSTIS-0 complete ***
#
#     *** CALSTIS-0 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:35:40 MDT
#
#     Input    o8ru3xhdq_raw.fits
#     Outroot  ./o8ru3xhdq_raw.fits
#     Warning  CRCORR will be omitted because there's only one imset.
#
#     *** CALSTIS-1 -- Version 3.4.2 (19-Jan-2018) ***
#     Begin    25-Aug-2023 14:35:40 MDT
#     Input    o8ru3xhdq_raw.fits
#     Output   ./o8ru3xhdq_flt.fits
#     OBSMODE  ACCUM
#     APERTURE 52X0.2
#     OPT_ELEM G750L
#     DETECTOR CCD
#
#     Imset 1  Begin 14:35:40 MDT
#     Epcfile  o8ru3xhdj_epc.fits
#
#     CCDTAB   oref$0841734do_ccd.fits
#     CCDTAB   PEDIGREE=INFLIGHT 12/07/2001 20/07/2002
#     CCDTAB   DESCRIP =Updated readnoise for gain={1,4}, all amps, binning=1x1------------
#     CCDTAB   DESCRIP =all bias frames; gain calibration from prop 9611
#     Warning  Only one imset, so CRCORR will be reset to SKIPPED.
#
#     DQICORR  PERFORM
#     DQITAB   oref$h1v11475o_bpx.fits
#     DQITAB   PEDIGREE=GROUND
#     DQITAB   DESCRIP =Prel. Ground Calib
#     DQICORR  COMPLETE
#
#     ATODCORR OMIT
#
#     BLEVCORR PERFORM
#     Warning  (blevcorr) No virtual overscan region; \
#     Warning  no correction for slope will be applied.
#              Bias level from overscan has been subtracted; \
#              mean of bias levels subtracted was 1520.18.
#     BLEVCORR COMPLETE
#              Uncertainty array initialized, readnoise=7.6399, gain=4.021
#
#     BIASCORR PERFORM
#     BIASFILE oref$o2o1502to_bia.fits
#     BIASFILE PEDIGREE=INFLIGHT 24/01/2004 08/02/2004
#     BIASFILE DESCRIP =Reference file created by STIS bias pipeline
#     BIASCORR COMPLETE
#
#     DARKCORR PERFORM
#     DARKFILE oref$u691336co_drk.fits
#     DARKFILE PEDIGREE=INFLIGHT 24/01/2004 01/02/2004
#     DARKFILE DESCRIP =Weekly Dark created with the Dark Reference File Pipeline----------
#     DARKCORR COMPLETE
#
#     FLATCORR PERFORM
#     PFLTFILE oref$n491401no_pfl.fits
#     PFLTFILE PEDIGREE=INFLIGHT 16/08/2001 25/11/2002
#     PFLTFILE DESCRIP =ON-ORBIT CCD P-FLAT
#     LFLTFILE oref$pcc2026ko_lfl.fits
#     LFLTFILE PEDIGREE=INFLIGHT 27/05/1997 27/05/1997
#     LFLTFILE DESCRIP =CCD G750L Low-Order Flat
#     FLATCORR COMPLETE
#
#     SHADCORR OMIT
#
#     PHOTCORR OMIT
#
#     STATFLAG PERFORM
#     STATFLAG COMPLETE
#     Imset 1  End 14:35:40 MDT
#
#     End      25-Aug-2023 14:35:40 MDT
#
#     *** CALSTIS-1 complete ***
#
#     End      25-Aug-2023 14:35:40 MDT
#
#     *** CALSTIS-0 complete ***
# mkfringeflat.py version 0.1
#  - matching fringes in a flatfield to those in science data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 31
#      28 if os.path.exists('{}_frr.fits'.format(flatpath)):
#      29     os.remove('{}_frr.fits'.format(flatpath))
# ---> 31 stistools.defringe.mkfringeflat('{}_{}.fits'.format(scipath, prod_type), '{}_nsp.fits'.format(flatpath),
#      32                                 '{}_frr.fits'.format(flatpath), beg_shift=-0.5, end_shift=2, shift_step=0.1,
#      33                                 beg_scale=0.8, end_scale=1.7, scale_step=0.04)
#      35 stistools.defringe.defringe('{}_{}.fits'.format(scipath, prod_type), '{}_frr.fits'.format(flatpath), overwrite=True)
#      37 outpath = '{}defringed/'.format(path)
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/stistools/defringe/mkfringeflat.py:117, in mkfringeflat(inspec, inflat, outflat, do_shift, beg_shift, end_shift, shift_step, do_scale, beg_scale, end_scale, scale_step, extrloc, extrsize, opti_spreg, rms_region)
#     114 print("mkfringeflat.py version {}".format(__version__))
#     115 print(" - matching fringes in a flatfield to those in science data")
# --> 117 sci_hdulist = fits.open(inspec)
#     118 flt_hdulist = fits.open(inflat)
#     120 scidata = sci_hdulist[1].data
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:214, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#     211 if not name:
#     212     raise ValueError(f"Empty filename: {name!r}")
# --> 214 return HDUList.fromfile(
#     215     name,
#     216     mode,
#     217     memmap,
#     218     save_backup,
#     219     cache,
#     220     lazy_load_hdus,
#     221     ignore_missing_simple,
#     222     use_fsspec=use_fsspec,
#     223     fsspec_kwargs=fsspec_kwargs,
#     224     **kwargs,
#     225 )
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:482, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     462 @classmethod
#     463 def fromfile(
#     464     cls,
#    (...)
#     472     **kwargs,
#     473 ):
#     474     """
#     475     Creates an `HDUList` instance from a file-like object.
#     476
#    (...)
#     479     documentation for details of the parameters accepted by this method).
#     480     """
# --> 482     return cls._readfrom(
#     483         fileobj=fileobj,
#     484         mode=mode,
#     485         memmap=memmap,
#     486         save_backup=save_backup,
#     487         cache=cache,
#     488         ignore_missing_simple=ignore_missing_simple,
#     489         lazy_load_hdus=lazy_load_hdus,
#     490         **kwargs,
#     491     )
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1170, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#    1167 if fileobj is not None:
#    1168     if not isinstance(fileobj, _File):
#    1169         # instantiate a FITS file object (ffo)
# -> 1170         fileobj = _File(
#    1171             fileobj,
#    1172             mode=mode,
#    1173             memmap=memmap,
#    1174             cache=cache,
#    1175             use_fsspec=use_fsspec,
#    1176             fsspec_kwargs=fsspec_kwargs,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/anaconda3/envs/stenv/lib/python3.10/site-packages/astropy/io/fits/file.py:636, in _File._open_filename(self, filename, mode, overwrite)
#     633 ext = os.path.splitext(self.name)[1]
#     635 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 636     self._file = open(self.name, IO_FITS_MODES[mode])
#     637     self.close_on_error = True
#     639 # Make certain we're back at the beginning of the file
#     640 # BZ2File does not support seek when the file is open for writing, but
#     641 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/david/2tb_ext_hd/hddata/hwo/data/hst/HIP-15457/stis/o8ru3xhdq_crj.fits'

# %% [markdown]
# Ok give up on that for now, might ask helpdesk.
